# %% [markdown]
# # Return Sort by Oldest on Youtube

# %%
import scrapetube
from tabulate import tabulate

channelurl = input("Channel url: ")

videos = scrapetube.get_channel(channel_url= channelurl)

url = "https://www.youtube.com/watch?v="

vidlist = []
vidTitle = []
vidUploadTime = []

for video in videos:
    vidlist.append(url + str(video['videoId']))    
    
    vidTitle.append(video['title']['runs'][0]['text'])

    vidUploadTime.append(video['publishedTimeText']['simpleText'])
    

vidlist = vidlist[::-1]
vidTitle = vidTitle[::-1]
vidUploadTime = vidUploadTime[::-1]

numVids = ''
 
while numVids not in range(len(vidlist)): 
    numVids = int(input(f"How many old videos do you want to see? \nThe channel has total {len(vidlist)} videos(excluding shorts) \nBe sensible with your choice \nChoosing a number too high might disrupt the output: "))
    if numVids not in range(len(vidlist)):
        print("Invalid choice")

data = {'Title' : vidTitle[:numVids], 'Uploaded' : vidUploadTime[:numVids], 'Url': vidlist[:numVids]}

print(tabulate(data, headers='keys', tablefmt='double_grid',  maxcolwidths=[55,10,55], showindex = "always"))

input("Press any key to exit...")
# Out:
# Channel url: https://www.youtube.com/@KirtiChow
# How many old videos do you want to see?
# The channel has total 59 videos(excluding shorts)
# Be sensible with your choice
# Choosing a number too high might disrupt the output: 30
# ╔════╦════════════╦═════════════╦═════════════════════════════════════════════╗
# ║    ║ Title      ║ Uploaded    ║ Url                                         ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║  0 ║ We All     ║ 4 years ago ║ https://www.youtube.com/watch?v=0CkuBDtwYL4 ║
# ║    ║ Have That  ║             ║                                             ║
# ║    ║ One Friend ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║  1 ║ When I     ║ 4 years ago ║ https://www.youtube.com/watch?v=svNoKxbHZP8 ║
# ║    ║ Broke My   ║             ║                                             ║
# ║    ║ Foot       ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║  2 ║ Worst      ║ 4 years ago ║ https://www.youtube.com/watch?v=SkapfRDEbKo ║
# ║    ║ School     ║             ║                                             ║
# ║    ║ Holiday    ║             ║                                             ║
# ║    ║ Experience ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║  3 ║ Neighbors  ║ 4 years ago ║ https://www.youtube.com/watch?v=4KF6aBqCKAY ║
# ║    ║ & Horror   ║             ║                                             ║
# ║    ║ Videos |   ║             ║                                             ║
# ║    ║ My Experie ║             ║                                             ║
# ║    ║ nces       ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║  4 ║ THINGS     ║ 4 years ago ║ https://www.youtube.com/watch?v=uo20S6kp0Sc ║
# ║    ║ WRONG WITH ║             ║                                             ║
# ║    ║ OUR        ║             ║                                             ║
# ║    ║ GENERATION ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║  5 ║ MEANING Of ║ 4 years ago ║ https://www.youtube.com/watch?v=MyoKALeX-nA ║
# ║    ║ BFF (Best  ║             ║                                             ║
# ║    ║ Fake       ║             ║                                             ║
# ║    ║ Friend)    ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║  6 ║ INDIAN     ║ 4 years ago ║ https://www.youtube.com/watch?v=aWaXqXxFqWc ║
# ║    ║ WEIRD      ║             ║                                             ║
# ║    ║ NAMES      ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║  7 ║ Struggles  ║ 4 years ago ║ https://www.youtube.com/watch?v=zzqEOwEhE28 ║
# ║    ║ Of A       ║             ║                                             ║
# ║    ║ Science    ║             ║                                             ║
# ║    ║ Student!   ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║  8 ║ Why You    ║ 4 years ago ║ https://www.youtube.com/watch?v=hXU1HyN1e_w ║
# ║    ║ Should NOT ║             ║                                             ║
# ║    ║ Watch Big  ║             ║                                             ║
# ║    ║ Boss!      ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║  9 ║ Getting    ║ 4 years ago ║ https://www.youtube.com/watch?v=wmdlR9fk3O0 ║
# ║    ║ Into A New ║             ║                                             ║
# ║    ║ School Exp ║             ║                                             ║
# ║    ║ erience!   ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 10 ║ How        ║ 3 years ago ║ https://www.youtube.com/watch?v=4uG4owE3lO8 ║
# ║    ║ Bollywood  ║             ║                                             ║
# ║    ║ Is         ║             ║                                             ║
# ║    ║ Destroying ║             ║                                             ║
# ║    ║ Your       ║             ║                                             ║
# ║    ║ Mindset!   ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 11 ║ SCHOOL     ║ 3 years ago ║ https://www.youtube.com/watch?v=yplE_jxE7Mg ║
# ║    ║ CANTEEN    ║             ║                                             ║
# ║    ║ STORIES    ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 12 ║ That WEIRD ║ 3 years ago ║ https://www.youtube.com/watch?v=5avhXL9MuCw ║
# ║    ║ Guy In     ║             ║                                             ║
# ║    ║ Every      ║             ║                                             ║
# ║    ║ Class      ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 13 ║ EXCUSES    ║ 3 years ago ║ https://www.youtube.com/watch?v=v2IQSRMcbjs ║
# ║    ║ for not    ║             ║                                             ║
# ║    ║ going      ║             ║                                             ║
# ║    ║ school     ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 14 ║ Only LAZY  ║ 3 years ago ║ https://www.youtube.com/watch?v=pdFD35xlVBk ║
# ║    ║ People Can ║             ║                                             ║
# ║    ║ Understand ║             ║                                             ║
# ║    ║ This Video ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 15 ║ Cheating   ║ 3 years ago ║ https://www.youtube.com/watch?v=JlwzpfFgOoc ║
# ║    ║ In School  ║             ║                                             ║
# ║    ║ Examinatio ║             ║                                             ║
# ║    ║ ns         ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 16 ║ A Girl In  ║ 3 years ago ║ https://www.youtube.com/watch?v=RciNo6pRwoU ║
# ║    ║ My College ║             ║                                             ║
# ║    ║ Chased Me! ║             ║                                             ║
# ║    ║ |          ║             ║                                             ║
# ║    ║ Storytime  ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 17 ║ INDIAN     ║ 3 years ago ║ https://www.youtube.com/watch?v=qIfBGWylafw ║
# ║    ║ MOMS ARE   ║             ║                                             ║
# ║    ║ THE BEST!  ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 18 ║ Boards     ║ 3 years ago ║ https://www.youtube.com/watch?v=4Lonqrj6X8k ║
# ║    ║ Exams | Ek ║             ║                                             ║
# ║    ║ Dard Bhari ║             ║                                             ║
# ║    ║ Dastaan    ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 19 ║ That One   ║ 3 years ago ║ https://www.youtube.com/watch?v=RG7vKr2Y-Tw ║
# ║    ║ Friend Who ║             ║                                             ║
# ║    ║ Is Always  ║             ║                                             ║
# ║    ║ Late!      ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 20 ║ Types Of   ║ 3 years ago ║ https://www.youtube.com/watch?v=Q1gDq21R92o ║
# ║    ║ People In  ║             ║                                             ║
# ║    ║ A Local    ║             ║                                             ║
# ║    ║ Bus        ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 21 ║ You Should ║ 3 years ago ║ https://www.youtube.com/watch?v=NQPiV2qagik ║
# ║    ║ STOP       ║             ║                                             ║
# ║    ║ Playing    ║             ║                                             ║
# ║    ║ PUBG!      ║             ║                                             ║
# ║    ║ (Here's    ║             ║                                             ║
# ║    ║ Why)       ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 22 ║ College In ║ 3 years ago ║ https://www.youtube.com/watch?v=ECZCSwDUuHs ║
# ║    ║ ternships  ║             ║                                             ║
# ║    ║ | Ek Dhoka ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 23 ║ The Harsh  ║ 3 years ago ║ https://www.youtube.com/watch?v=IbBvvsHxaqk ║
# ║    ║ Truth      ║             ║                                             ║
# ║    ║ About      ║             ║                                             ║
# ║    ║ TikTok     ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 24 ║ How To     ║ 3 years ago ║ https://www.youtube.com/watch?v=A9RHAdY-OVY ║
# ║    ║ Become A   ║             ║                                             ║
# ║    ║ Successful ║             ║                                             ║
# ║    ║ YouTuber   ║             ║                                             ║
# ║    ║ (PARODY)   ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 25 ║ People     ║ 3 years ago ║ https://www.youtube.com/watch?v=sHlTMmB46B4 ║
# ║    ║ Afraid Of  ║             ║                                             ║
# ║    ║ Dogs | Dog ║             ║                                             ║
# ║    ║ goPhobia   ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 26 ║ What       ║ 3 years ago ║ https://www.youtube.com/watch?v=QIPS-M7HJas ║
# ║    ║ Marvel     ║             ║                                             ║
# ║    ║ Movies     ║             ║                                             ║
# ║    ║ Taught Us! ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 27 ║ Why We     ║ 3 years ago ║ https://www.youtube.com/watch?v=NUQfbr_SBaM ║
# ║    ║ Should BAN ║             ║                                             ║
# ║    ║ Summers!   ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 28 ║ Don't      ║ 3 years ago ║ https://www.youtube.com/watch?v=cpp6VSwNBWk ║
# ║    ║ BLAME The  ║             ║                                             ║
# ║    ║ Indian     ║             ║                                             ║
# ║    ║ Education  ║             ║                                             ║
# ║    ║ System     ║             ║                                             ║
# ╠════╬════════════╬═════════════╬═════════════════════════════════════════════╣
# ║ 29 ║ My Awkward ║ 3 years ago ║ https://www.youtube.com/watch?v=eWwAKTmqgWw ║
# ║    ║ Stage Perf ║             ║                                             ║
# ║    ║ ormance In ║             ║                                             ║
# ║    ║ School!    ║             ║                                             ║
# ║    ║ (GONE      ║             ║                                             ║
# ║    ║ WRONG)     ║             ║                                             ║
# ╚════╩════════════╩═════════════╩═════════════════════════════════════════════╝
# Press any key to exit...
# ''
